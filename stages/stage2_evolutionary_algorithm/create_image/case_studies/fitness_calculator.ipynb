# %%
import stk
from pathlib import Path
import sys

# %%
sys.path.append('/rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_3/parametrisation')
sys.path.append('/rds/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image')
from fitness import fitness_calculator

# %%
finished_runs = list(Path.cwd().glob('case_study*/**/run*_finished'))

# %%
for i, run in enumerate(finished_runs):
    for generation in run.glob('stk_ea_runs/0/scratch/generation_*.json'):
        print(f'Loading {generation.stem}')
        generation_num = str(generation.stem).split('_')[1]
        pop = stk.EAPopulation.load(str(generation))
        print(f'{len(pop)} cages have been loaded from the generation.')
        print(f'Setting fitness values using calculator.')
        pop.set_fitness_values_from_calculators(
            fitness_calculator,
            num_processes=1,
        )
        if not write_path.exists():
            write_path = run.joinpath('stk_ea_runs', f'fitness_generation_{generation_num}.json')
            print(f'Writing generation {generation_num} to {str(write_path)}.')
            pop.dump(str(write_path), include_attrs=['sa_score', 'pore_diameter', 'largest_window', 'window_std', 'sc_score'], ignore_missing_attrs=False)
        else:
            print(f'{write_path} already exists.')
# Out:
# Loading generation_48
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# Writing generation 48 to /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json.
# Loading generation_4
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_31
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_26
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_33
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_11
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_40
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_1
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_32
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_47
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_22
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_24
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_17
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_9
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_23
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_46
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_21
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_37
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_6
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_44
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_27
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_38
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_34
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_19
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_16
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_15
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_43
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_10
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_8
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_35
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_45
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_36
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_42
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_49
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_30
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_2
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_12
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_28
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_5
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_14
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_29
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_3
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_20
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_18
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_25
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_7
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_39
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_13
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_41
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_48
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_4
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_31
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_26
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_33
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_11
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_40
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_1
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_32
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_47
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_22
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_24
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_17
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_9
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_23
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_46
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_21
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_37
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_6
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_44
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_27
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_38
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_34
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_19
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_16
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_15
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_43
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_10
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_8
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_35
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_45
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_36
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_42
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_49
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_30
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_2
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_12
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_28
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_5
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_14
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_29
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_3
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_20
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_18
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_25
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_7
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_39
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_13
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_41
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_48
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_4
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_31
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_26
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_33
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_11
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_40
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_1
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_32
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_47
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_22
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_24
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_17
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_9
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_23
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_46
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_21
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_37
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_6
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_44
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_27
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_38
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_34
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_19
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_16
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_15
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
# /rdsgpfs/general/user/sb2518/home/WORK/main_projects/synthetic_accessibility_project/stages/stage2_evolutionary_algorithm/create_image/case_studies/case_study_2_pore_volume/No_SA/run2_finished/stk_ea_runs/fitness_generation_48.json already exists.
# Loading generation_43
# 25 cages have been loaded from the generation.
# Setting fitness values using calculator.
